# %% [markdown]
# 신경망의 기초 개념

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 학습순서 :
#   1. 순전파 forward : 입력 데이터가 신경망을 통해 출력으로 전달
#   2. 손실 계산 : 예측갑시과 실제값의 차이를 계산
#   3. 역전파 : 오차를 기반으로 가중치와 바이어스를 업데이트
#   4. 최적화 optimizer : 경사하강법등의 알고리즘을 통해 가중치를 최적화

# %% [markdown]
# xor 문제

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# %%
# xor 데이터 생성
x = np.array([[0,0],[0,1],[1,0],[1,1]]  )
y = np.array([0,1,1,0 ])
colors = [ 'red' if label ==0 else 'blue' for label in y  ]
plt.figure(figsize=(6,6))
plt.scatter(x[:,0],x[:,1],c=colors,alpha=0.5)
plt.axvline(0.5, color='gray', linestyle='--',linewidth=0.5)
plt.axhline(0.5, color='gray', linestyle='--',linewidth=0.5)
plt.xlabel('x1')
plt.ylabel('x2')
plt.grid(True)
plt.show()
