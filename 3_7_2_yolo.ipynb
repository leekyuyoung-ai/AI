# %%
# !wget -O /content/dataset.zip "https://public.roboflow.com/ds/GpOg81Cp28?key=ByAt1iLNFQ"

# %%
# !unzip /content/dataset.zip -d /content/dataset

# %%
# !pip install ultralytics
from ultralytics import YOLO
model = YOLO("yolo11n.pt")

# %%
model.train(
    data="/content/dataset/data.yaml",
    epochs=10,
    batch=16,
    imgsz=640
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# 학습된 모델 로드

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')
results = model.predict(source='/content/dataset/train/images', save=True)
# Out:
# image 1/448 /content/dataset/train/images/IMG_2274_jpeg_jpg.rf.2f319e949748145fb22dcb52bb325a0c.jpg: 640x480 (no detections), 15.3ms
# image 2/448 /content/dataset/train/images/IMG_2275_jpeg_jpg.rf.66355520a49ba7fb7082052f7ca6fee0.jpg: 640x480 (no detections), 10.7ms
# image 3/448 /content/dataset/train/images/IMG_2276_jpeg_jpg.rf.7411b1902c81bad8cdefd2cc4eb3a97b.jpg: 640x480 (no detections), 10.9ms
# image 4/448 /content/dataset/train/images/IMG_2280_jpeg_jpg.rf.5abcce5be523f6507bbaf731dd671226.jpg: 640x480 1 fish, 10.2ms
# image 5/448 /content/dataset/train/images/IMG_2282_jpeg_jpg.rf.510f3bc14c3e0aa378b192199d01cae6.jpg: 640x480 (no detections), 16.4ms
# image 6/448 /content/dataset/train/images/IMG_2283_jpeg_jpg.rf.4f28032102ddc4534410f9bf474ef1d0.jpg: 640x480 (no detections), 15.9ms
# image 7/448 /content/dataset/train/images/IMG_2284_jpeg_jpg.rf.99de11cb5727748bd3eae3afe7b415e6.jpg: 640x480 (no detections), 13.0ms
# ...

# %%
print(results[0].names)
print(results[0].save_dir)
# Out:
# {0: 'fish', 1: 'jellyfish', 2: 'penguin', 3: 'puffin', 4: 'shark', 5: 'starfish', 6: 'stingray'}
# runs/detect/predict11

# %%
lists = []
for result in results:
  if result.boxes.xyxy.size(0) > 0:
    lists.append(result)

# %%
len(lists)
# Out:
# 11

# %%
lists[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'fish', 1: 'jellyfish', 2: 'penguin', 3: 'puffin', 4: 'shark', 5: 'starfish', 6: 'stingray'}
# obb: None
# orig_img: array([[[165,  58,   1],
#         [164,  59,   2],
#         [166,  61,   4],
#         ...,
#         [255,  35,   3],
#         [255,  36,   4],
#         [255,  36,   4]],
#
#        [[167,  58,   2],
#         [168,  59,   3],
#         [168,  61,   4],
#         ...,
#         [255,  35,   3],
#         [255,  36,   4],
#         [255,  36,   4]],
#
#        [[171,  58,   1],
#         [172,  59,   2],
#         [171,  61,   3],
#         ...,
#         [255,  35,   3],
#         [255,  36,   4],
#         [255,  36,   4]],
#
#        ...,
#
#        [[107,  53,  23],
#         [109,  55,  25],
#         [113,  57,  28],
#         ...,
#         [ 71,  33,  21],
#         [ 72,  33,  24],
# ...

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('/content/dataset/train/images/IMG_2280_jpeg_jpg.rf.5abcce5be523f6507bbaf731dd671226.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
lists[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=768x1024>
